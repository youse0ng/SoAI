# %% [markdown]
# # Training의 라벨링 데이터

# %%
import pandas as pd
import json
import os 
import glob

# %%
train_data = pd.DataFrame()
PATH = '../Data/Training/02.라벨링데이터'
folder_names = os.listdir('../Data/Training/02.라벨링데이터/')
for folder in folder_names:
    for jsonfile in glob.glob(os.path.join(PATH,folder,'*.json')):
        with open(jsonfile,'r') as f:
            data = json.load(f)
            if data['patient']['diagnosis'] >= 5: 
                records = {
                    'Filename': data['filename'],
                    'ImagePath': data['imagePath'],
                    'Class': data['patient']['diagnosis'],
                    'Point': None,
                    'Caption': data['caption']
                }
            else:
                records = {
                    'Filename': data['filename'],
                    'ImagePath': data['imagePath'],
                    'Class': data['patient']['diagnosis'],
                    'Point': data['shapes'][0]['points'],
                    'Caption': data['caption']
                }
            train_data = pd.concat([train_data, pd.DataFrame([records])], ignore_index=True)

# %%
train_data['ImagePath'] = train_data['ImagePath'].apply(lambda x: "TS_"+x.replace('/','_'))

# %%
import joblib
joblib.dump(train_data,'Train_Data.pkl')
# Out:
# ['Train_Data.pkl']

# %% [markdown]
# # DataBase에 들어갈 데이터

# %%
df = joblib.load('../Dataset/Validation_Data.pkl')
df = df.drop(columns= ['Filename','ImageWidth','ImageHeight'])
df['ImagePath'] = df['ImagePath'].apply(lambda x: x.split('.')[-1])
# joblib.dump(df,'DataBase.pkl')
df
# Out:
#     ImagePath  Class                                            Caption  Age  \
# 0    선천성유문협착증      1  This plain abdominal supine radiograph shows m...    6
# 1    선천성유문협착증      1  This supine plain abdominal radiograph shows m...    5
# 2    선천성유문협착증      1  This plain abdominal supine radiograph of an a...    6
# 3    선천성유문협착증      1  This plain supine abdominal radiograph of an a...    3
# 4    선천성유문협착증      1  This plain supine abdominal radiograph shows m...    7
# ..        ...    ...                                                ...  ...
# 995        정상      5  This plain abdominal radiograph shows a non-sp...    4
# 996        정상      5  This plain abdominal radiograph shows an unrem...    3
# 997        정상      5  This plain abdominal radiograph shows no remar...    6
# 998        정상      5  This plain abdominal radiograph reveals no pat...    7
# 999        정상      5  This plain abdominal radiograph shows a nonspe...    4
#
#                                              ImageFile PatientName
# 0    ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...         윤경경
# 1    ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...         박재진
# 2    ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...         정경도
# 3    ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...         강호경
# 4    ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...         김선수
# ..                                                 ...         ...
# 995     ../Data/Validation/01.원천데이터/VS_2.정상/5_1955.png         조서경
# 996     ../Data/Validation/01.원천데이터/VS_2.정상/5_1956.png         강우호
# 997     ../Data/Validation/01.원천데이터/VS_2.정상/5_1957.png         최우영
# 998     ../Data/Validation/01.원천데이터/VS_2.정상/5_1958.png         정경우
# 999     ../Data/Validation/01.원천데이터/VS_2.정상/5_1959.png         강준도
#
# [1000 rows x 6 columns]

# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. MariaDB 연결 설정
user = 'root'            # 사용자 계정
password = 'Yousung0528!'     # 비밀번호
host = 'localhost'       # 호스트 (또는 '127.0.0.1')
port = '3306'            # 기본 포트
database = 'Xray'        # 사용할 데이터베이스명

# 2. 연결 엔진 생성
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# 3. 데이터프레임 읽기
df = joblib.load('DataBase.pkl')  # 또는 이미 df가 존재할 경우 생략

# 4. 테이블에 저장
df.to_sql(name='xray_data', con=engine, if_exists='replace', index=False)  # 'append'도 가능
# Out:
# 1000

# %% [markdown]
# # 평가 데이터 라벨링데이터

# %% [markdown]
# - 비고: 3 ~ 7세로 Random Age로 할당했다.

# %%
validation_data = pd.DataFrame()
PATH = '../Data/Validation/02.라벨링데이터'
folder_names = os.listdir('../Data/Validation/02.라벨링데이터/')
for folder in folder_names:
    for jsonfile in glob.glob(os.path.join(PATH,folder,'*.json')):
        with open(jsonfile,'r') as f:
            data = json.load(f)
            if data['patient']['diagnosis'] >= 5: 
                records = {
                    'Filename': data['filename'],
                    'ImagePath': data['imagePath'],
                    'Class': data['patient']['diagnosis'],
                    'Caption': data['caption'],
                    'ImageWidth': data['imageWidth'],
                    'ImageHeight': data['imageHeight'],
                    'Age': data['patient']['age']
                }
            else:
                records = {
                    'Filename': data['filename'],
                    'ImagePath': data['imagePath'],
                    'Class': data['patient']['diagnosis'],
                    'Caption': data['caption'],
                    'ImageWidth': data['imageWidth'],
                    'ImageHeight': data['imageHeight'],
                    'Age': data['patient']['age']
                }
            validation_data = pd.concat([validation_data, pd.DataFrame([records])], ignore_index=True)
validation_data
# Out:
#        Filename        ImagePath  Class  \
# 0    1_1814.png  1.질환/1.선천성유문협착증      1
# 1    1_1815.png  1.질환/1.선천성유문협착증      1
# 2    1_1816.png  1.질환/1.선천성유문협착증      1
# 3    1_1817.png  1.질환/1.선천성유문협착증      1
# 4    1_1818.png  1.질환/1.선천성유문협착증      1
# ..          ...              ...    ...
# 995  5_1955.png             2.정상      5
# 996  5_1956.png             2.정상      5
# 997  5_1957.png             2.정상      5
# 998  5_1958.png             2.정상      5
# 999  5_1959.png             2.정상      5
#
#                                                Caption  ImageWidth  \
# 0    This plain abdominal supine radiograph shows m...         512
# 1    This supine plain abdominal radiograph shows m...         512
# 2    This plain abdominal supine radiograph of an a...         512
# 3    This plain supine abdominal radiograph of an a...         512
# 4    This plain supine abdominal radiograph shows m...         512
# ..                                                 ...         ...
# 995  This plain abdominal radiograph shows a non-sp...         512
# 996  This plain abdominal radiograph shows an unrem...         512
# 997  This plain abdominal radiograph shows no remar...         512
# 998  This plain abdominal radiograph reveals no pat...         512
# 999  This plain abdominal radiograph shows a nonspe...         512
#
#      ImageHeight   Age
# 0            512  None
# 1            512  None
# 2            512  None
# 3            512  None
# 4            512  None
# ..           ...   ...
# 995          512  None
# 996          512  None
# 997          512  None
# 998          512  None
# 999          512  None
#
# [1000 rows x 7 columns]

# %%
import random
validation_data['ImagePath'] = validation_data['ImagePath'].apply(lambda x: "VS_"+x.replace('/','_'))
validation_data['Age'] = validation_data['Age'].apply(lambda x: random.randint(3,7))
validation_data
# Out:
#        Filename           ImagePath  Class  \
# 0    1_1814.png  VS_1.질환_1.선천성유문협착증      1
# 1    1_1815.png  VS_1.질환_1.선천성유문협착증      1
# 2    1_1816.png  VS_1.질환_1.선천성유문협착증      1
# 3    1_1817.png  VS_1.질환_1.선천성유문협착증      1
# 4    1_1818.png  VS_1.질환_1.선천성유문협착증      1
# ..          ...                 ...    ...
# 995  5_1955.png             VS_2.정상      5
# 996  5_1956.png             VS_2.정상      5
# 997  5_1957.png             VS_2.정상      5
# 998  5_1958.png             VS_2.정상      5
# 999  5_1959.png             VS_2.정상      5
#
#                                                Caption  ImageWidth  \
# 0    This plain abdominal supine radiograph shows m...         512
# 1    This supine plain abdominal radiograph shows m...         512
# 2    This plain abdominal supine radiograph of an a...         512
# 3    This plain supine abdominal radiograph of an a...         512
# 4    This plain supine abdominal radiograph shows m...         512
# ..                                                 ...         ...
# 995  This plain abdominal radiograph shows a non-sp...         512
# 996  This plain abdominal radiograph shows an unrem...         512
# 997  This plain abdominal radiograph shows no remar...         512
# 998  This plain abdominal radiograph reveals no pat...         512
# 999  This plain abdominal radiograph shows a nonspe...         512
#
#      ImageHeight  Age
# 0            512    6
# 1            512    5
# 2            512    6
# 3            512    3
# 4            512    7
# ..           ...  ...
# 995          512    4
# 996          512    3
# 997          512    6
# 998          512    7
# 999          512    4
#
# [1000 rows x 7 columns]

# %%
import os
validation_data['ImageFile'] = validation_data.apply(
    lambda row: os.path.join('../Data/Validation/01.원천데이터', row['ImagePath'], row['Filename']),
    axis=1
)
validation_data.iloc[0]['ImageFile']
# Out:
# '../Data/Validation/01.원천데이터\\VS_1.질환_1.선천성유문협착증\\1_1814.png'

# %%
validation_data.drop(columns=['Filename'],inplace=True)

# %%
validation_data
# Out:
#        Filename           ImagePath  Class  \
# 0    1_1814.png  VS_1.질환_1.선천성유문협착증      1
# 1    1_1815.png  VS_1.질환_1.선천성유문협착증      1
# 2    1_1816.png  VS_1.질환_1.선천성유문협착증      1
# 3    1_1817.png  VS_1.질환_1.선천성유문협착증      1
# 4    1_1818.png  VS_1.질환_1.선천성유문협착증      1
# ..          ...                 ...    ...
# 995  5_1955.png             VS_2.정상      5
# 996  5_1956.png             VS_2.정상      5
# 997  5_1957.png             VS_2.정상      5
# 998  5_1958.png             VS_2.정상      5
# 999  5_1959.png             VS_2.정상      5
#
#                                                Caption  ImageWidth  \
# 0    This plain abdominal supine radiograph shows m...         512
# 1    This supine plain abdominal radiograph shows m...         512
# 2    This plain abdominal supine radiograph of an a...         512
# 3    This plain supine abdominal radiograph of an a...         512
# 4    This plain supine abdominal radiograph shows m...         512
# ..                                                 ...         ...
# 995  This plain abdominal radiograph shows a non-sp...         512
# 996  This plain abdominal radiograph shows an unrem...         512
# 997  This plain abdominal radiograph shows no remar...         512
# 998  This plain abdominal radiograph reveals no pat...         512
# 999  This plain abdominal radiograph shows a nonspe...         512
#
#      ImageHeight  Age                                          ImageFile
# 0            512    4  ../Data/Validation/01.원천데이터\VS_1.질환_1.선천성유문협착증...
# 1            512    4  ../Data/Validation/01.원천데이터\VS_1.질환_1.선천성유문협착증...
# 2            512    6  ../Data/Validation/01.원천데이터\VS_1.질환_1.선천성유문협착증...
# 3            512    7  ../Data/Validation/01.원천데이터\VS_1.질환_1.선천성유문협착증...
# 4            512    6  ../Data/Validation/01.원천데이터\VS_1.질환_1.선천성유문협착증...
# ..           ...  ...                                                ...
# 995          512    7     ../Data/Validation/01.원천데이터\VS_2.정상\5_1955.png
# 996          512    5     ../Data/Validation/01.원천데이터\VS_2.정상\5_1956.png
# 997          512    4     ../Data/Validation/01.원천데이터\VS_2.정상\5_1957.png
# 998          512    5     ../Data/Validation/01.원천데이터\VS_2.정상\5_1958.png
# 999          512    7     ../Data/Validation/01.원천데이터\VS_2.정상\5_1959.png
#
# [1000 rows x 8 columns]

# %%
validation_data['ImageFile'] = validation_data['ImageFile'].apply(lambda x: x.replace("\\","/"))
import PIL.Image
PIL.Image.open(validation_data.iloc[0]['ImageFile'])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
import joblib
import random
import pandas as pd
# 예시 데이터프레임 (당신의 실제 df를 사용하세요)
# df = pd.read_csv('your_data.csv')

# 성씨 리스트 (자주 쓰이는 10개)
last_names = ['김', '이', '박', '최', '정', '강', '조', '윤', '장', '임']

# 이름 글자 리스트 (두 글자 이름용)
first_name_syllables = ['민', '서', '지', '윤', '하', '준', '도', '현', '우', '수', '경', '선', '영', '호', '태', '재', '성', '호', '민', '진']

def generate_korean_name():
    last = random.choice(last_names)
    first = random.choice(first_name_syllables) + random.choice(first_name_syllables)
    return last + first

# 1000개 고유 이름 생성
unique_names = set()
while len(unique_names) < len(validation_data):
    unique_names.add(generate_korean_name())

unique_names = list(unique_names)
random.shuffle(unique_names)

# PatientName 컬럼으로 추가
validation_data['PatientName'] = unique_names

# 결과 확인
validation_data.head()
joblib.dump(validation_data,'Validation_Data.pkl')
# Out:
# ['Validation_Data.pkl']

# %%
validation_data.head()
# Out:
#                ImagePath  Class  \
# 0  VS_VS_1.질환_1.선천성유문협착증      1
# 1  VS_VS_1.질환_1.선천성유문협착증      1
# 2  VS_VS_1.질환_1.선천성유문협착증      1
# 3  VS_VS_1.질환_1.선천성유문협착증      1
# 4  VS_VS_1.질환_1.선천성유문협착증      1
#
#                                              Caption  ImageWidth  ImageHeight  \
# 0  This plain abdominal supine radiograph shows m...         512          512
# 1  This supine plain abdominal radiograph shows m...         512          512
# 2  This plain abdominal supine radiograph of an a...         512          512
# 3  This plain supine abdominal radiograph of an a...         512          512
# 4  This plain supine abdominal radiograph shows m...         512          512
#
#    Age                                          ImageFile PatientName
# 0    3  ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...         최수재
# 1    6  ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...         윤선민
# 2    4  ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...         정하민
# 3    5  ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...         정영윤
# 4    4  ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...         이민도
